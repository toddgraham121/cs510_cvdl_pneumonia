# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
train_loss_vgg = [0.3935, 0.1958, 0.1721, 0.1775, 0.1519, 0.1545, 0.1474, 0.1396, 0.1389, 0.1304, 0.1136, 0.1275, 0.1189, 0.1389, 0.1042, 0.1295, 0.1134, 0.1211, 0.1156]
train_acc_vgg = [0.8227, 0.9240, 0.9295, 0.9285, 0.9388, 0.9403, 0.9415, 0.9440, 0.9452, 0.9483, 0.9538, 0.9537, 0.9556, 0.9488, 0.9609, 0.9478, 0.9539, 0.9485, 0.9609]
val_loss_vgg = [0.3961, 0.2868, 0.2680, 0.3731, 0.3767, 0.2945, 0.3838, 0.3615, 0.2575, 0.2580, 0.3479, 0.3498, 0.3410, 0.3932, 0.4693, 0.4016, 0.2788, 0.2614, 0.4382]
val_acc_vgg = [0.8301, 0.8862, 0.8894, 0.8574, 0.8526, 0.8878, 0.8478, 0.8542, 0.8942, 0.8894, 0.8638, 0.8654, 0.8686, 0.8494, 0.8205, 0.8494, 0.8798, 0.8846, 0.8429]

# %%
train_loss_resnet = [0.5839, 0.4256, 0.3983, 0.3741, 0.3454, 0.3239, 0.3249, 0.3276, 0.3281, 0.3110, 0.3268, 0.3117, 0.3140, 0.2992, 0.3000, 0.2910, 0.2675, 0.3055, 0.2899, 0.2705, 0.2848, 0.2750, 0.2754, 0.2543, 0.2703, 0.2685, 0.2754, 0.2693, 0.2606, 0.2571, 0.2646, 0.2694, 0.2588, 0.2527, 0.2684, 0.2509, 0.2466, 0.2575, 0.2550, 0.2516]
train_acc_resnet = [0.7434, 0.7887, 0.8059, 0.8290, 0.8437, 0.8564, 0.8552, 0.8560, 0.8560, 0.8629, 0.8556, 0.8624, 0.8650, 0.8708, 0.8742, 0.8736, 0.8889, 0.8623, 0.8771, 0.8796, 0.8787, 0.8801, 0.8836, 0.8983, 0.8921, 0.8919, 0.8821, 0.8845, 0.8974, 0.9014, 0.8910, 0.8857, 0.8904, 0.8979, 0.8857, 0.8900, 0.8961, 0.8964, 0.9009, 0.8970]
val_loss_resnet = [0.5180, 0.5230, 0.5508, 0.3976, 0.4582, 0.3708, 0.3647, 0.4313, 0.4745, 0.4060, 0.3762, 0.4103, 0.4466, 0.3470, 0.4367, 0.3349, 0.3329, 0.3506, 0.3721, 0.4103, 0.3691, 0.3453, 0.3353, 0.3153, 0.3079, 0.3991, 0.4239, 0.3225, 0.3094, 0.3396, 0.3566, 0.3276, 0.3067, 0.5475, 0.3096, 0.2891, 0.3395, 0.4335, 0.3342, 0.2855]
val_acc_resnet = [0.7340, 0.7452, 0.7532, 0.8253, 0.7901, 0.8494, 0.8446, 0.8157, 0.8077, 0.8333, 0.8397, 0.8173, 0.8093, 0.8622, 0.8173, 0.8766, 0.8670, 0.8558, 0.8446, 0.8285, 0.8510, 0.8510, 0.8654, 0.8814, 0.8750, 0.8381, 0.8253, 0.8702, 0.8942, 0.8558, 0.8526, 0.8702, 0.8942, 0.7772, 0.8782, 0.8942, 0.8526, 0.7997, 0.8590, 0.8990]

# %%
epochs = np.arange(1,41)
plt.plot(epochs, train_acc_resnet, label='ResNet152 Train')
plt.plot(epochs, val_acc_resnet, label='ResNet152 Validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('ResNet152 Training and Validation Accuracy')
plt.legend()

# %%
epochs = np.arange(1,20)
plt.plot(epochs, train_acc_vgg, label='VGG16 Train')
plt.plot(epochs, val_acc_vgg, label='VGG16 Validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('VGG16 Training and Validation Accuracy')
plt.xticks(np.arange(0, 20, 5))
plt.legend()

# %%
epochs = np.arange(1,41)
plt.plot(epochs, train_loss_resnet, label='ResNet152 Train')
plt.plot(epochs, val_loss_resnet, label='ResNet152 Validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('ResNet152 Training and Validation Loss')
plt.legend()

# %%
epochs = np.arange(1,20)
plt.plot(epochs, train_loss_vgg, label='VGG16 Train')
plt.plot(epochs, val_loss_vgg, label='VGG16 Validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.title('VGG16 Training and Validation Loss')
plt.xticks(np.arange(0, 20, 5))
plt.legend()
